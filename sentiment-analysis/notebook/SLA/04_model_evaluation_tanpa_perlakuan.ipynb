# %%
# 4.1 Import Library & Konfigurasi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                             f1_score, accuracy_score, confusion_matrix,
                             classification_report, precision_score, recall_score)

# Konfigurasi Visualisasi
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['font.size'] = 12

# Path File (DISESUAIKAN UNTUK SLA)
MODEL_FILE = '../../outputs/SLA/sla_sentiment_clean_tanpa_perlakuan.csv'
GT_FILE = '../../outputs/evaluation/ground_truth_final.csv'
OUTPUT_DIR = '../../outputs/evaluation'

print(f"[INFO] Library dimuat. Konfigurasi evaluasi SLA siap.")
# Out:
# [INFO] Library dimuat. Konfigurasi evaluasi SLA siap.

# %%
# Cell 4.2 Load Data
df_gt = pd.read_csv(GT_FILE)
df_model = pd.read_csv(MODEL_FILE)

df_eval = df_gt[['no', 'ground_truth_category', 'ground_truth_scaled']].merge(
    df_model[['no', 'compound_score', 'sentiment']],
    on='no',
    how='inner'
)
print(f"[INFO] Data hasil merge: {len(df_eval)} baris")
print(df_eval.head())
# Out:
# [INFO] Data hasil merge: 450 baris
#     no ground_truth_category  ground_truth_scaled  compound_score sentiment
# 0   50              positive                 0.20       -0.853113  negative
# 1   84              positive                 0.20        0.773915  positive
# 2   89              negative                -0.70       -0.933788  negative
# 3  101              positive                 0.20        0.898624  positive
# 4  121              positive                 0.15       -0.819240  negative

# %%
# 4.2.1 Validasi Data Ground Truth
df_gt
# Out:
#         no                 timestamp  \
# 0       50  2016-12-24T13:54:06.000Z
# 1       84  2016-12-21T08:47:51.000Z
# 2       89  2016-12-20T18:32:07.000Z
# 3      101  2016-12-20T04:39:14.000Z
# 4      121  2016-12-18T04:07:09.000Z
# ..     ...                       ...
# 445  13032  2025-11-11T14:24:58.000Z
# 446  13057  2025-11-10T15:20:53.000Z
# 447  13138  2025-11-05T04:02:54.000Z
# 448  13174  2025-11-02T16:04:00.000Z
# 449  13190  2025-11-01T03:36:57.000Z
#
#                                                   teks  \
# 0    Komisi IX Ketua Komisi IX DPR RI merekomendasi...
# 1    Dapilku Rumahku Reses dan silaturahim bersama ...
# 2    mengharukan wakil rakyat trlalu banyak waktuny...
# 3    Ketua dan Para Wakil Ketua DPR RI PERLUNYA RUU...
# 4    Viva Anggota DPR Minta TNI AU Investigasi Kece...
# ..                                                 ...
# 445  Hai SahabatBahari Selasa November Badan Mutu K...
# 446  gue nggak bodoh bodoh amat gue deserve punya p...
# 447  Gpp lah boss DANA RESES DPRRI aja uang APBN UA...
# 448  Sabtu November pukul WIB bertempat di Hotel Gr...
# 449  Ia menilai kebijakan pensiun seumur hidup untu...
#
#                                         teks_processed  ground_truth_mean  \
# 0    komisi IX ketua komisi IX DPR RI rekomendasi k...                0.8
# 1    dapilku rumah reses dan silaturahim sama anggo...                0.8
# 2    haru wakil rakyat terlalu banyak waktu untuk u...               -2.8
# 3    ketua dan para wakil ketua DPR RI PERLU RUU LA...                0.8
# 4    viva anggota DPR minta TNI AU investigasi cela...                0.6
# ..                                                 ...                ...
# 445  hai sahabatbahari selasa november badan mutu K...                0.4
# 446  saya tidak bodoh bodoh banget saya deserve pun...               -1.8
# 447  enggak apa - apa lah bos DANA RESES DPRRI saja...               -3.6
# 448  sabtu november pukul WIB tempat di hotel grand...                0.8
# 449  ia nilai kebijakan pensiun umur hidup untuk an...               -2.6
#
#      ground_truth_scaled  sd_annotator ground_truth_category
# 0                   0.20      0.447214              positive
# 1                   0.20      0.447214              positive
# 2                  -0.70      0.447214              negative
# 3                   0.20      0.447214              positive
# 4                   0.15      0.547723              positive
# ..                   ...           ...                   ...
# 445                 0.10      0.547723              positive
# 446                -0.45      1.303840              negative
# 447                -0.90      0.547723              negative
# 448                 0.20      0.447214              positive
# 449                -0.65      0.547723              negative
#
# [450 rows x 8 columns]

# %%
# 4.2.2 Validasi Data Model
df_model
# Out:
#         no                 timestamp  \
# 0       50  2016-12-24T13:54:06.000Z
# 1       84  2016-12-21T08:47:51.000Z
# 2       89  2016-12-20T18:32:07.000Z
# 3      101  2016-12-20T04:39:14.000Z
# 4      121  2016-12-18T04:07:09.000Z
# ..     ...                       ...
# 445  13032  2025-11-11T14:24:58.000Z
# 446  13057  2025-11-10T15:20:53.000Z
# 447  13138  2025-11-05T04:02:54.000Z
# 448  13174  2025-11-02T16:04:00.000Z
# 449  13190  2025-11-01T03:36:57.000Z
#
#                                                   teks  \
# 0    Komisi IX Ketua Komisi IX DPR RI merekomendasi...
# 1    Dapilku Rumahku Reses dan silaturahim bersama ...
# 2    mengharukan wakil rakyat trlalu banyak waktuny...
# 3    Ketua dan Para Wakil Ketua DPR RI PERLUNYA RUU...
# 4    Viva Anggota DPR Minta TNI AU Investigasi Kece...
# ..                                                 ...
# 445  Hai SahabatBahari Selasa November Badan Mutu K...
# 446  gue nggak bodoh bodoh amat gue deserve punya p...
# 447  Gpp lah boss DANA RESES DPRRI aja uang APBN UA...
# 448  Sabtu November pukul WIB bertempat di Hotel Gr...
# 449  Ia menilai kebijakan pensiun seumur hidup untu...
#
#                                         teks_processed sentiment  \
# 0    komisi IX ketua komisi IX DPR RI rekomendasi k...  negative
# 1    dapilku rumah reses dan silaturahim sama anggo...  positive
# 2    haru wakil rakyat terlalu banyak waktu untuk u...  negative
# 3    ketua dan para wakil ketua DPR RI PERLU RUU LA...  positive
# 4    viva anggota DPR minta TNI AU investigasi cela...  negative
# ..                                                 ...       ...
# 445  hai sahabatbahari selasa november badan mutu K...  positive
# 446  saya tidak bodoh bodoh banget saya deserve pun...  negative
# 447  enggak apa - apa lah bos DANA RESES DPRRI saja...  negative
# 448  sabtu november pukul WIB tempat di hotel grand...  negative
# 449  ia nilai kebijakan pensiun umur hidup untuk an...  positive
#
#      compound_score
# 0         -0.853113
# 1          0.773915
# 2         -0.933788
# 3          0.898624
# 4         -0.819240
# ..              ...
# 445        0.951157
# 446       -0.989698
# 447       -0.576701
# 448       -0.900070
# 449        0.876441
#
# [450 rows x 6 columns]

# %%
# 4.3 Skala Evaluasi — Fix: tidak ada human_visual_score
y_true_scaled = df_eval['ground_truth_scaled']
y_pred_scaled = df_eval['compound_score']

# Untuk scatter plot nanti, y_human_visual = ground_truth_scaled
y_human_visual = df_eval['ground_truth_scaled']  # ← ini yang benar
y_model_pred = df_eval['compound_score']

print("[INFO] Persiapan metrik evaluasi selesai.")
# Out:
# [INFO] Persiapan metrik evaluasi selesai.

# %%
# 4.4 Hitung Pearson dan Spearman (Linear dan Monotonic Relationship)
# Hitung Pearson dan Spearman
pearson_r, p_val = pearsonr(y_true_scaled, y_pred_scaled)
spearman_rho, p_val_s = spearmanr(y_true_scaled, y_pred_scaled)

# Hitung Error Metrics
rmse = np.sqrt(mean_squared_error(y_true_scaled, y_pred_scaled))
mae = mean_absolute_error(y_true_scaled, y_pred_scaled)
r2 = np.corrcoef(y_true_scaled, y_pred_scaled)[0, 1]**2 

print("=== HASIL EVALUASI CONTINUOUS SCORE (SLA+TANPA PERLAKUAN) ===")
print(f"Pearson Correlation (r)    : {pearson_r:.2f}")
print(f"Spearman Rank (rho)        : {spearman_rho:.2f}")
print(f"RMSE (Root Mean Sq. Error) : {rmse:.2f}")
print(f"MAE (Mean Abs. Error)      : {mae:.2f}")
print(f"R-Squared (R²)             : {r2:.2f}")
# Out:
# === HASIL EVALUASI CONTINUOUS SCORE (SLA+TANPA PERLAKUAN) ===
# Pearson Correlation (r)    : 0.52
# Spearman Rank (rho)        : 0.52
# RMSE (Root Mean Sq. Error) : 0.60
# MAE (Mean Abs. Error)      : 0.51
# R-Squared (R²)             : 0.27

# %%
# 4.5 Evaluasi Kategorikal dengan Threshold ±0.05
# Fungsi kategorisasi berdasarkan threshold standar ±0.05
def categorize(score):
    if score >= 0.20: return 'positive'
    elif score <= -0.20: return 'negative'
    else: return 'neutral'

df_eval['pred_class'] = df_eval['compound_score'].apply(categorize)
df_eval['gt_class'] = df_eval['ground_truth_category']

labels = ['negative', 'neutral', 'positive']

# Hitung Metrik Klasifikasi
acc = accuracy_score(df_eval['gt_class'], df_eval['pred_class'])
f1_macro = f1_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', labels=labels)

print("HASIL EVALUASI KLASIFIKASI (SLA+TANPA PERLAKUAN)")
print(f"Accuracy        : {acc:.2f}")
print(f"F1-Score (Macro): {f1_macro:.2f}")
print("-" * 50)
print("Classification Report SLA+TANPA PERLAKUAN:")
print(classification_report(df_eval['gt_class'], df_eval['pred_class'], target_names=labels, zero_division=0))
# Out:
# HASIL EVALUASI KLASIFIKASI (SLA+TANPA PERLAKUAN)
# Accuracy        : 0.58
# F1-Score (Macro): 0.54
# --------------------------------------------------
# Classification Report SLA+TANPA PERLAKUAN:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.72      0.68       170
#      neutral       0.52      0.22      0.31       123
#     positive       0.55      0.71      0.62       157
#
#     accuracy                           0.58       450
#    macro avg       0.57      0.55      0.54       450
# weighted avg       0.57      0.58      0.56       450

# %%
df_eval['error'] = df_eval['gt_class'] != df_eval['pred_class']
misclassified = df_eval[df_eval['error']].sample(50)
for _, row in misclassified.iterrows():
    print(f"Tweet: {df_gt[df_gt['no'] == row['no']]['teks_processed'].values[0][:100]}...")
    print(f"GT: {row['gt_class']} | Pred: {row['pred_class']} | Score: {row['compound_score']:.3f}")
    print("-" * 80)
# Out:
# Tweet: lama DPR telah selesai RUU nasional RUU DPRRI...
# GT: positive | Pred: negative | Score: -0.516
# --------------------------------------------------------------------------------
# Tweet: mohon info bagaimana maju ruu_jasa_konstruksi ?...
# GT: negative | Pred: positive | Score: 0.527
# --------------------------------------------------------------------------------
# Tweet: anggota DPR RI tuh ada orang semua pilih langsung oleh masyarakat atau dari partai dan mereka yang j...
# GT: positive | Pred: negative | Score: -0.924
# --------------------------------------------------------------------------------
# Tweet: DPR umum susun anggota pansus RUU pemilu...
# GT: neutral | Pred: positive | Score: 0.368
# --------------------------------------------------------------------------------
# Tweet: DPR gali masuk soal RUU CSR ikibangsaku...
# GT: positive | Pred: negative | Score: -0.368
# --------------------------------------------------------------------------------
# Tweet: presiden sudah kirim surat ke DPR RI untuk bahas RUU ubah UU ITE...
# GT: neutral | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: lapas sibolga ikut giat kunjung kerja reses komisi XII DPR RI...
# GT: neutral | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: undang undang tembakau tekan kendali impor...
# GT: neutral | Pred: negative | Score: -0.202
# --------------------------------------------------------------------------------
# Tweet: agenda DPR rabu pukul WIB rapat paripurna DPR RI agendadpr...
# GT: neutral | Pred: positive | Score: 0.368
# --------------------------------------------------------------------------------
# Tweet: panja komisi VII DPR RI RUU tentang penyelenggaraan ibadah haji dan umrah RDP kepala pusat sehat haj...
# GT: neutral | Pred: positive | Score: 0.899
# --------------------------------------------------------------------------------
# Tweet: kakanwil BPN provinsi sumatera selatan bpk h muchtar SH MM terima kunjung kerja reses bpk h wahyu sa...
# GT: neutral | Pred: positive | Score: 0.951
# --------------------------------------------------------------------------------
# Tweet: senin depan rapat buka bahas RUU taxamnesty...
# GT: neutral | Pred: positive | Score: 0.527
# --------------------------------------------------------------------------------
# Tweet: baleg tuju RUU larang praktik monopoli...
# GT: positive | Pred: negative | Score: -0.516
# --------------------------------------------------------------------------------
# Tweet: RUU KUHP target selesai periode ini...
# GT: negative | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: gubernur dan plt sekda tidak hadir rapat paripurna wakil rakyat pulau riau kepri...
# GT: neutral | Pred: negative | Score: -0.801
# --------------------------------------------------------------------------------
# Tweet: bantu arief rahman satriyo dapat lebih banyak tanda tangan tanda tangan perlu !...
# GT: neutral | Pred: positive | Score: 0.906
# --------------------------------------------------------------------------------
# Tweet: DPR RI minta TV dukungan RUU siar...
# GT: neutral | Pred: positive | Score: 0.577
# --------------------------------------------------------------------------------
# Tweet: pelaksanaan perkosa bocah tahun masih bebas anggota DPR RI desakan kapolda aceh turun tangan...
# GT: positive | Pred: negative | Score: -0.501
# --------------------------------------------------------------------------------
# Tweet: dewan wakil rakyat daerah DPRD kabupaten pesisir barat sibar gelar rapat paripurna dengan agenda pen...
# GT: neutral | Pred: positive | Score: 0.850
# --------------------------------------------------------------------------------
# Tweet: jika saya jadi anggota DPR saya niat lurus kebijakan ini beres RUU kewirausahaan misal UU kita harus...
# GT: positive | Pred: negative | Score: -0.943
# --------------------------------------------------------------------------------
# Tweet: formappi partai nasdem paling sering bolos...
# GT: negative | Pred: neutral | Score: 0.103
# --------------------------------------------------------------------------------
# Tweet: DPR RI banget RUU HIP masih agenda...
# GT: negative | Pred: positive | Score: 0.219
# --------------------------------------------------------------------------------
# Tweet: agenda DPR rabu pukul WIB baleg DPR rapat panja harmonisasi RUU siar agendadpr...
# GT: neutral | Pred: positive | Score: 0.713
# --------------------------------------------------------------------------------
# Tweet: anda lihat pintar main kata debat tetapi anda belum lihat pintar realisasi janji bagai wakil rakyat ...
# GT: negative | Pred: positive | Score: 0.354
# --------------------------------------------------------------------------------
# Tweet: selamat jalan bhayangkara...
# GT: neutral | Pred: positive | Score: 0.202
# --------------------------------------------------------------------------------
# Tweet: ketua DPR RI tanggap soal keputusan MKD perihal kesetjenan DPR RI untuk potong anggaran reses anggot...
# GT: neutral | Pred: negative | Score: -0.983
# --------------------------------------------------------------------------------
# Tweet: sidang paripurna di DPR RI yang bahas RUU pemilu telah selesai laksana ach elshintanewsandtalk...
# GT: neutral | Pred: negative | Score: -0.629
# --------------------------------------------------------------------------------
# Tweet: godok RUU sadap anggota DPR kami tidak ada takut...
# GT: neutral | Pred: negative | Score: -0.730
# --------------------------------------------------------------------------------
# Tweet: ketua komisi XI DPR RI mukhamad misbakhun sebut PDI juang sikap mencla mencle soal kebijakan naik pa...
# GT: negative | Pred: positive | Score: 0.879
# --------------------------------------------------------------------------------
# Tweet: DPR sahkan UU laksana hukum kebiri JAKARTA SUKA pihak DPR RI akhir pengesahan undang undang UU...
# GT: positive | Pred: negative | Score: -0.368
# --------------------------------------------------------------------------------
# Tweet: anggota DPR RUU ITE acu keputusan MAKA indonesia...
# GT: neutral | Pred: negative | Score: -0.713
# --------------------------------------------------------------------------------
# Tweet: sangat free hatin ruang rapat paripurna DPR RI...
# GT: negative | Pred: neutral | Score: 0.193
# --------------------------------------------------------------------------------
# Tweet: rapat paripurna dewan wakil rakyat dah provinsi jawa barat jumat agenda ubah hasil banmus ambil sump...
# GT: neutral | Pred: positive | Score: 0.202
# --------------------------------------------------------------------------------
# Tweet: tunggu RUU siar di sahkan oleh...
# GT: negative | Pred: positive | Score: 0.368
# --------------------------------------------------------------------------------
# Tweet: RUU tax amnesty lang ke paripurna DPR RI...
# GT: positive | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: reses dpr ri dasco kunjung KANGEN kab tangerang...
# GT: neutral | Pred: positive | Score: 0.778
# --------------------------------------------------------------------------------
# Tweet: komisi IX ketua komisi IX DPR RI rekomendasi kepada pem agar tinjau ulang kebijakan bebas visa...
# GT: positive | Pred: negative | Score: -0.853
# --------------------------------------------------------------------------------
# Tweet: anggota komisi IX DPR kurniasih mufidayati usul karantina bagi jalan luar negeri jadi hingga hari ku...
# GT: positive | Pred: negative | Score: -0.480
# --------------------------------------------------------------------------------
# Tweet: dewan wakil rakyat DPR minta pengaturan turun dari undang undang UU no tahun tentang didik...
# GT: positive | Pred: negative | Score: -0.522
# --------------------------------------------------------------------------------
# Tweet: diah pitaloka anggota panja RUU hapus keras seksual komisi VII DPR RI ajak serta yang hadir serta ba...
# GT: positive | Pred: neutral | Score: 0.186
# --------------------------------------------------------------------------------
# Tweet: komisi kali DPR RI sosialisasi undang undang sistem buku di kalimantan selatan kunkerdpr...
# GT: positive | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: reses dpr_ri di SMK muhammadiyah bandung asyik deh sekolah ini punya jurus agribisnis salah satu kem...
# GT: positive | Pred: neutral | Score: -0.103
# --------------------------------------------------------------------------------
# Tweet: baleg DPR tidak temu halang saat usul RUU PKS masuk dalam bahas program legislasi nasional prolegnas...
# GT: positive | Pred: negative | Score: -0.743
# --------------------------------------------------------------------------------
# Tweet: lanjut baleg DPR RI bahas DIM RUU karantina sehat...
# GT: neutral | Pred: positive | Score: 0.819
# --------------------------------------------------------------------------------
# Tweet: untuk tangan sampah perlu perspektif bangsa yang holistik ta hanya oleh mang kebijakan tap...
# GT: neutral | Pred: negative | Score: -0.927
# --------------------------------------------------------------------------------
# Tweet: langsung rapat paripurna DPR RI ke masa sidang II tahu sidang selasa bahas agenda tuju lap baleg ten...
# GT: neutral | Pred: positive | Score: 0.948
# --------------------------------------------------------------------------------
# Tweet: JAKARTA anggota komisi IX DPR RI ahmad zainuddin sambut baik kebijakan badan penyelenggaraan jamin s...
# GT: positive | Pred: negative | Score: -0.401
# --------------------------------------------------------------------------------
# Tweet: lintasinfo suasana jelang rapat paripurna di rep...
# GT: neutral | Pred: positive | Score: 0.822
# --------------------------------------------------------------------------------
# Tweet: ruang rapat paripurna DPR RI...
# GT: neutral | Pred: negative | Score: -0.629
# --------------------------------------------------------------------------------
# Tweet: komisi IX ajar program harga pas dan anak tokcer komisi IX DPR RI dalam masa reses sidang II tahun s...
# GT: neutral | Pred: positive | Score: 0.926
# --------------------------------------------------------------------------------

# %%
# 4.6 Tabel Metrik Utama
acc = accuracy_score(df_eval['gt_class'], df_eval['pred_class'])
prec = precision_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)
rec = recall_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)
f1 = f1_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)

metrics_df = pd.DataFrame([{
    'Konfigurasi': 'SLA+TANPA PERLAKUAN',
    'Accuracy': f"{acc:.2f}",
    'Precision (M)': f"{prec:.2f}",
    'Recall (M)': f"{rec:.2f}",
    'F1-Score (M)': f"{f1:.2f}"
}])

metrics_df
# Out:
#            Konfigurasi Accuracy Precision (M) Recall (M) F1-Score (M)
# 0  SLA+TANPA PERLAKUAN     0.58          0.57       0.55         0.54

# %%
# 4.7 Visualisasi: Scatter Plot dan Regression Line
plt.figure(figsize=(8, 6))

# Scatter Plot: X = Model (-1,1), Y = Human (-1,1)
sns.scatterplot(x=y_model_pred, y=y_human_visual, alpha=0.4, color='black', s=20)

# Garis Merah: Garis regresi ideal (y = x * 4)
x_vals = np.linspace(-1, 1, 100)
y_vals = x_vals 
plt.plot(x_vals, y_vals, color='red', linestyle='--', linewidth=2, label='Perfect Correlation Line')

# Konfigurasi Sumbu
plt.xlim(-1.1, 1.1)
plt.ylim(-1.1, 1.1)
plt.xticks(np.arange(-1, 1.1, 0.5))
plt.yticks(np.arange(-1, 1.1, 0.5))

plt.xlabel('Model Compound Score', fontsize=12, fontweight='bold')
plt.ylabel('Mean of 20 Human Judges', fontsize=12, fontweight='bold')
plt.title(f'Sentiment Correlation\nPearson r = {pearson_r:.2f}', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

os.makedirs(OUTPUT_DIR, exist_ok=True)
plt.savefig(f'{OUTPUT_DIR}/scatter_plot_SLA_tanpa_perlakuan.png', dpi=300, bbox_inches='tight')
plt.show()

print("[INFO] Scatter plot tersimpan.")
# Out:
# [INFO] Scatter plot tersimpan.

# %%
# 4.8 Visualisasi Confusion Matrix
plt.figure(figsize=(8, 6))

# Hitung Confusion Matrix
cm = confusion_matrix(df_eval['gt_class'], df_eval['pred_class'], labels=labels)

# Heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Neg', 'Neu', 'Pos'], 
            yticklabels=['Neg', 'Neu', 'Pos'],
            annot_kws={"size": 14, "weight": "bold"})

plt.title('Confusion Matrix (Threshold ±0.05)', fontsize=14, fontweight='bold')
plt.ylabel('Ground Truth (Human)', fontsize=12, fontweight='bold')
plt.xlabel('Prediction (Model)', fontsize=12, fontweight='bold')

plt.savefig(f'{OUTPUT_DIR}/confusion_matrix_SLA_tanpa_perlakuan.png', dpi=300, bbox_inches='tight')
plt.show()

print("[INFO] Confusion matrix tersimpan.")
print("[INFO] Proses evaluasi selesai!")
# Out:
# [INFO] Confusion matrix tersimpan.
# [INFO] Proses evaluasi selesai!

# %%
# 4.9 Menyimpan Hasil
prec = precision_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)
rec = recall_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)

metrics_df = pd.DataFrame([{
    'Konfigurasi': 'SLA+TANPA PERLAKUAN',
    'Accuracy': f"{acc:.2f}",
    'Precision (M)': f"{prec:.2f}",
    'Recall (M)': f"{rec:.2f}",
    'F1-Score (M)': f"{f1_macro:.2f}",
    'Pearson-r': f"{pearson_r:.2f}"
}])

# Simpan ke CSV
metrics_df.to_csv(os.path.join(OUTPUT_DIR, 'evaluation_metrics_SLA_tanpa_perlakuan.csv'), index=False)

# Simpan JSON Summary
eval_summary = {
    'konfigurasi': 'SLA+TANPA PERLAKUAN',
    'dataset_size': len(df_eval),
    'metrics': metrics_df.iloc[0].to_dict()
}
with open(os.path.join(OUTPUT_DIR, 'evaluation_summary_SLA_tanpa_perlakuan.json'), 'w') as f:
    json.dump(eval_summary, f, indent=2)

print("\n[INFO] Evaluasi SLA+TANPA PERLAKUAN Selesai. Data metrik telah disimpan.")
metrics_df
# Out:
# [INFO] Evaluasi SLA+TANPA PERLAKUAN Selesai. Data metrik telah disimpan.
#            Konfigurasi Accuracy Precision (M) Recall (M) F1-Score (M)  \
# 0  SLA+TANPA PERLAKUAN     0.58          0.57       0.55         0.54
#
#   Pearson-r
# 0      0.52
