# %%
# 4.1 Import Library & Konfigurasi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                             f1_score, accuracy_score, confusion_matrix,
                             classification_report, precision_score, recall_score)

# Konfigurasi Visualisasi
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['font.size'] = 12

# Path File
MODEL_FILE = '../../outputs/RSN/rsn_sentiment_clean_with_ignore.csv'
GT_FILE = '../../outputs/evaluation/ground_truth_final.csv'
OUTPUT_DIR = '../../outputs/evaluation'

print(f"[INFO] Library dimuat. Konfigurasi evaluasi RSN siap.")
# Out:
# [INFO] Library dimuat. Konfigurasi evaluasi RSN siap.

# %%
# Cell 4.2 Load Data
df_gt = pd.read_csv(GT_FILE)
df_model = pd.read_csv(MODEL_FILE)

df_eval = df_gt[['no', 'ground_truth_category', 'ground_truth_scaled']].merge(
    df_model[['no', 'compound_score', 'sentiment']],
    on='no',
    how='inner'
)
print(f"[INFO] Data hasil merge: {len(df_eval)} baris")
print(df_eval.head())
# Out:
# [INFO] Data hasil merge: 450 baris
#     no ground_truth_category  ground_truth_scaled  compound_score sentiment
# 0   50              positive                 0.20       -0.826809  negative
# 1   84              positive                 0.20        0.515993  positive
# 2   89              negative                -0.70       -0.923251  negative
# 3  101              positive                 0.20        0.853113  positive
# 4  121              positive                 0.15       -0.853113  negative

# %%
# 4.2.1 Validasi Data Ground Truth
df_gt
# Out:
#         no                 timestamp  \
# 0       50  2016-12-24T13:54:06.000Z
# 1       84  2016-12-21T08:47:51.000Z
# 2       89  2016-12-20T18:32:07.000Z
# 3      101  2016-12-20T04:39:14.000Z
# 4      121  2016-12-18T04:07:09.000Z
# ..     ...                       ...
# 445  13032  2025-11-11T14:24:58.000Z
# 446  13057  2025-11-10T15:20:53.000Z
# 447  13138  2025-11-05T04:02:54.000Z
# 448  13174  2025-11-02T16:04:00.000Z
# 449  13190  2025-11-01T03:36:57.000Z
#
#                                                   teks  \
# 0    Komisi IX Ketua Komisi IX DPR RI merekomendasi...
# 1    Dapilku Rumahku Reses dan silaturahim bersama ...
# 2    mengharukan wakil rakyat trlalu banyak waktuny...
# 3    Ketua dan Para Wakil Ketua DPR RI PERLUNYA RUU...
# 4    Viva Anggota DPR Minta TNI AU Investigasi Kece...
# ..                                                 ...
# 445  Hai SahabatBahari Selasa November Badan Mutu K...
# 446  gue nggak bodoh bodoh amat gue deserve punya p...
# 447  Gpp lah boss DANA RESES DPRRI aja uang APBN UA...
# 448  Sabtu November pukul WIB bertempat di Hotel Gr...
# 449  Ia menilai kebijakan pensiun seumur hidup untu...
#
#                                         teks_processed  ground_truth_mean  \
# 0    komisi IX ketua komisi IX DPR RI merekomendasi...                0.8
# 1    dapilku rumahku reses dan silaturahim bersama ...                0.8
# 2    mengharukan wakil rakyat terlalu banyak waktun...               -2.8
# 3    ketua dan para wakil ketua DPR RI PERLUNYA RUU...                0.8
# 4    viva anggota DPR meminta TNI AU investigasi ke...                0.6
# ..                                                 ...                ...
# 445  hai sahabatbahari selasa november badan mutu K...                0.4
# 446  saya tidak bodoh bodoh sangat saya deserve pun...               -1.8
# 447  enggak apa - apa lah bos DANA RESES DPRRI saja...               -3.6
# 448  sabtu november pukul WIB bertempat di hotel gr...                0.8
# 449  ia menilai kebijakan pensiun seumur hidup untu...               -2.6
#
#      ground_truth_scaled  sd_annotator ground_truth_category
# 0                   0.20      0.447214              positive
# 1                   0.20      0.447214              positive
# 2                  -0.70      0.447214              negative
# 3                   0.20      0.447214              positive
# 4                   0.15      0.547723              positive
# ..                   ...           ...                   ...
# 445                 0.10      0.547723              positive
# 446                -0.45      1.303840              negative
# 447                -0.90      0.547723              negative
# 448                 0.20      0.447214              positive
# 449                -0.65      0.547723              negative
#
# [450 rows x 8 columns]

# %%
# 4.2.2 Validasi Data Model
df_model
# Out:
#         no                 timestamp  \
# 0       50  2016-12-24T13:54:06.000Z
# 1       84  2016-12-21T08:47:51.000Z
# 2       89  2016-12-20T18:32:07.000Z
# 3      101  2016-12-20T04:39:14.000Z
# 4      121  2016-12-18T04:07:09.000Z
# ..     ...                       ...
# 445  13032  2025-11-11T14:24:58.000Z
# 446  13057  2025-11-10T15:20:53.000Z
# 447  13138  2025-11-05T04:02:54.000Z
# 448  13174  2025-11-02T16:04:00.000Z
# 449  13190  2025-11-01T03:36:57.000Z
#
#                                                   teks  \
# 0    Komisi IX Ketua Komisi IX DPR RI merekomendasi...
# 1    Dapilku Rumahku Reses dan silaturahim bersama ...
# 2    mengharukan wakil rakyat trlalu banyak waktuny...
# 3    Ketua dan Para Wakil Ketua DPR RI PERLUNYA RUU...
# 4    Viva Anggota DPR Minta TNI AU Investigasi Kece...
# ..                                                 ...
# 445  Hai SahabatBahari Selasa November Badan Mutu K...
# 446  gue nggak bodoh bodoh amat gue deserve punya p...
# 447  Gpp lah boss DANA RESES DPRRI aja uang APBN UA...
# 448  Sabtu November pukul WIB bertempat di Hotel Gr...
# 449  Ia menilai kebijakan pensiun seumur hidup untu...
#
#                                         teks_processed sentiment  \
# 0    komisi IX ketua komisi IX DPR RI merekomendasi...  negative
# 1    dapilku rumahku reses dan silaturahim bersama ...  positive
# 2    mengharukan wakil rakyat terlalu banyak waktun...  negative
# 3    ketua dan para wakil ketua DPR RI PERLUNYA RUU...  positive
# 4    viva anggota DPR meminta TNI AU investigasi ke...  negative
# ..                                                 ...       ...
# 445  hai sahabatbahari selasa november badan mutu K...  positive
# 446  saya tidak bodoh bodoh sangat saya deserve pun...  negative
# 447  enggak apa - apa lah bos DANA RESES DPRRI saja...  positive
# 448  sabtu november pukul WIB bertempat di hotel gr...  positive
# 449  ia menilai kebijakan pensiun seumur hidup untu...  negative
#
#      compound_score
# 0         -0.826809
# 1          0.515993
# 2         -0.923251
# 3          0.853113
# 4         -0.853113
# ..              ...
# 445        0.878813
# 446       -0.270452
# 447        0.857000
# 448        0.202289
# 449       -0.898130
#
# [450 rows x 6 columns]

# %%
# 4.3 Skala Evaluasi — Fix: tidak ada human_visual_score
y_true_scaled = df_eval['ground_truth_scaled']
y_pred_scaled = df_eval['compound_score']

# Untuk scatter plot nanti, y_human_visual = ground_truth_scaled
y_human_visual = df_eval['ground_truth_scaled'] 
y_model_pred = df_eval['compound_score']

print("[INFO] Persiapan metrik evaluasi selesai.")
# Out:
# [INFO] Persiapan metrik evaluasi selesai.

# %%
# 4.4 Hitung Pearson dan Spearman (Linear dan Monotonic Relationship)
# Hitung Pearson dan Spearman
pearson_r, p_val = pearsonr(y_true_scaled, y_pred_scaled)
spearman_rho, p_val_s = spearmanr(y_true_scaled, y_pred_scaled)

# Hitung Error Metrics
rmse = np.sqrt(mean_squared_error(y_true_scaled, y_pred_scaled))
mae = mean_absolute_error(y_true_scaled, y_pred_scaled)
r2 = np.corrcoef(y_true_scaled, y_pred_scaled)[0, 1]**2 

print("=== HASIL EVALUASI CONTINUOUS SCORE (RSN+IGNORE) ===")
print(f"Pearson Correlation (r)    : {pearson_r:.2f}")
print(f"Spearman Rank (rho)        : {spearman_rho:.2f}")
print(f"RMSE (Root Mean Sq. Error) : {rmse:.2f}")
print(f"MAE (Mean Abs. Error)      : {mae:.2f}")
print(f"R-Squared (R²)             : {r2:.2f}")
# Out:
# === HASIL EVALUASI CONTINUOUS SCORE (RSN+IGNORE) ===
# Pearson Correlation (r)    : 0.55
# Spearman Rank (rho)        : 0.53
# RMSE (Root Mean Sq. Error) : 0.55
# MAE (Mean Abs. Error)      : 0.45
# R-Squared (R²)             : 0.30

# %%
# 4.5 Evaluasi Kategorikal dengan Threshold ±0.05
# Fungsi kategorisasi berdasarkan threshold standar ±0.05
def categorize(score):
    if score >= 0.05: return 'positive'
    elif score <= -0.05: return 'negative'
    else: return 'neutral'

df_eval['pred_class'] = df_eval['compound_score'].apply(categorize)
df_eval['gt_class'] = df_eval['ground_truth_category']

labels = ['negative', 'neutral', 'positive']

# Hitung Metrik Klasifikasi
acc = accuracy_score(df_eval['gt_class'], df_eval['pred_class'])
f1_macro = f1_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', labels=labels)

print("HASIL EVALUASI KLASIFIKASI (RSN+IGNORE)")
print(f"Accuracy        : {acc:.2f}")
print(f"F1-Score (Macro): {f1_macro:.2f}")
print("-" * 50)
print("Classification Report RSN+IGNORE:")
print(classification_report(df_eval['gt_class'], df_eval['pred_class'], target_names=labels, zero_division=0))
# Out:
# HASIL EVALUASI KLASIFIKASI (RSN+IGNORE)
# Accuracy        : 0.60
# F1-Score (Macro): 0.55
# --------------------------------------------------
# Classification Report RSN+IGNORE:
#               precision    recall  f1-score   support
#
#     negative       0.70      0.76      0.73       170
#      neutral       0.50      0.24      0.33       123
#     positive       0.53      0.69      0.60       157
#
#     accuracy                           0.60       450
#    macro avg       0.58      0.57      0.55       450
# weighted avg       0.59      0.60      0.57       450

# %%
df_eval['error'] = df_eval['gt_class'] != df_eval['pred_class']
misclassified = df_eval[df_eval['error']].sample(50)
for _, row in misclassified.iterrows():
    print(f"Tweet: {df_gt[df_gt['no'] == row['no']]['teks_processed'].values[0][:100]}...")
    print(f"GT: {row['gt_class']} | Pred: {row['pred_class']} | Score: {row['compound_score']:.3f}")
    print("-" * 80)
# Out:
# Tweet: pernyataan presiden joko widodo jokowi yang mengatakan jika komisi pemilihan umum KPU diberikan kewe...
# GT: negative | Pred: positive | Score: 0.915
# --------------------------------------------------------------------------------
# Tweet: jumat oktober badan legislasi DPR RI melaksanakan diplomasi parlemen ke national asemblea ecuador te...
# GT: positive | Pred: negative | Score: -0.915
# --------------------------------------------------------------------------------
# Tweet: meminta untuk fokus dalam membahas penyelesaian RUU pemilu...
# GT: negative | Pred: positive | Score: 0.881
# --------------------------------------------------------------------------------
# Tweet: mudahan SIAPAPUN BESOK YANG JADI PRESIDEN SEMOGA ANGGOTA DEWAN MEMBUAT RUU HUKUMAN MATI BAGI TERSANG...
# GT: positive | Pred: negative | Score: -0.939
# --------------------------------------------------------------------------------
# Tweet: panja komisi VII DPR RI RUU tentang penyelenggaraan ibadah haji dan umrah RDP kepala pusat kesehatan...
# GT: neutral | Pred: positive | Score: 0.774
# --------------------------------------------------------------------------------
# Tweet: dewan perwakilan rakyat DPR menggelar rapat paripurna tentang pemandangan umum fraksi fraksi atas ra...
# GT: neutral | Pred: positive | Score: 0.718
# --------------------------------------------------------------------------------
# Tweet: surat presiden naskah RUU cipta kerja serta naskah akademik yang menyertainya kepada ketua dan wakil...
# GT: neutral | Pred: positive | Score: 0.637
# --------------------------------------------------------------------------------
# Tweet: punya fungsi mengawasi yang dijamin undang undang...
# GT: neutral | Pred: positive | Score: 0.103
# --------------------------------------------------------------------------------
# Tweet: yth adnggota dpr beginikah mencerminkan wakil rakyat ?...
# GT: negative | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: sangat free hatin ruang rapat paripurna DPR RI...
# GT: negative | Pred: positive | Score: 0.193
# --------------------------------------------------------------------------------
# Tweet: mohon info bagaimana kemajuan ruu_jasa_konstruksi ?...
# GT: negative | Pred: positive | Score: 0.527
# --------------------------------------------------------------------------------
# Tweet: selamat pak BANG lancar hingga pelantikan...
# GT: neutral | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: DPR sahkan UU pelaksanaan hukuman kebiri JAKARTA SUKA pihak DPR RI akhirnya mengesahkan undang undan...
# GT: positive | Pred: negative | Score: -0.368
# --------------------------------------------------------------------------------
# Tweet: kenaikan tarif PPN ini diinisiasi oleh kementerian keuangan republik indonesia sri mulyani indrawati...
# GT: negative | Pred: positive | Score: 0.881
# --------------------------------------------------------------------------------
# Tweet: presiden sudah kirim surat ke DPR RI untuk bahas RUU perubahan UU ITE...
# GT: neutral | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: reses dpr ri dasco kunjungi KANGEN kab tangerang...
# GT: neutral | Pred: positive | Score: 0.778
# --------------------------------------------------------------------------------
# Tweet: rapat paripurna ke dipimpin oleh waka bang siang ini di ruang paripurna livestream...
# GT: neutral | Pred: negative | Score: -0.527
# --------------------------------------------------------------------------------
# Tweet: DPR gali masukan soal RUU CSR ikibangsaku...
# GT: positive | Pred: negative | Score: -0.368
# --------------------------------------------------------------------------------
# Tweet: siang jelang sore genkz PPN masih jadi buah bibir dalam lingkup masyarakat saat ini karena kebijakan...
# GT: positive | Pred: neutral | Score: -0.009
# --------------------------------------------------------------------------------
# Tweet: RUU pemilu segera divoting...
# GT: neutral | Pred: positive | Score: 0.629
# --------------------------------------------------------------------------------
# Tweet: dua anggota DPRD solsel dapil turun ke lapangan guna tampung aspirasi masyarakat pada penghujung tah...
# GT: neutral | Pred: positive | Score: 0.778
# --------------------------------------------------------------------------------
# Tweet: populer aturan cuti petahana sebaiknya opsional...
# GT: neutral | Pred: positive | Score: 0.527
# --------------------------------------------------------------------------------
# Tweet: ruang rapat paripurna DPR RI...
# GT: neutral | Pred: negative | Score: -0.629
# --------------------------------------------------------------------------------
# Tweet: media masyarakat dan publik harus mendorong DPR RI agar segera mengesahkan RUU TPKS rosmiati...
# GT: positive | Pred: negative | Score: -0.746
# --------------------------------------------------------------------------------
# Tweet: DPR RI menyetujui RUU APBN...
# GT: positive | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: massa demonstran penolakan perppu ormas menjadi undang undang hingga saat ini masih bertahan di depa...
# GT: negative | Pred: positive | Score: 0.382
# --------------------------------------------------------------------------------
# Tweet: kom penanya mahasiswa IPB tentang kebijakan impor ketergantungan impor merupakan kebijakan yang ada ...
# GT: neutral | Pred: positive | Score: 0.822
# --------------------------------------------------------------------------------
# Tweet: senin depan rapat terbuka bahas RUU taxamnesty...
# GT: neutral | Pred: positive | Score: 0.527
# --------------------------------------------------------------------------------
# Tweet: berikut berikut rekomendasi fraksi partai gerindra di terkait rancangan undang undang tentang pertan...
# GT: neutral | Pred: positive | Score: 0.382
# --------------------------------------------------------------------------------
# Tweet: info DPR RI akhirnya siapkan panja RUU tax amnesty...
# GT: positive | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: bantu arief rahman satriyo dapat lebih banyak tanda tangan tanda tangan diperlukan !...
# GT: neutral | Pred: positive | Score: 0.866
# --------------------------------------------------------------------------------
# Tweet: hukuman mati bagi yang korupsi lebih baik dibuat bersama daripada merevisi undang undang...
# GT: neutral | Pred: positive | Score: 0.617
# --------------------------------------------------------------------------------
# Tweet: reses bersama FPKB DPR RI melalui...
# GT: negative | Pred: positive | Score: 0.819
# --------------------------------------------------------------------------------
# Tweet: JOURNAL RESES DPR RI WARGA DESAK TETI NYALON BUPATI CILACAP via...
# GT: neutral | Pred: negative | Score: -0.062
# --------------------------------------------------------------------------------
# Tweet: DPR RI sahkan revisi RUU ITE...
# GT: positive | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: ketua badan legislasi DPR RI supratman andi agtas menyerahkan laporan baleg DPR RI terkait hasil pen...
# GT: neutral | Pred: positive | Score: 0.629
# --------------------------------------------------------------------------------
# Tweet: peringatan ini disampaikan dalam kunjungan kerja reses tim komisi II DPR RI di palembang sumatera se...
# GT: neutral | Pred: positive | Score: 0.774
# --------------------------------------------------------------------------------
# Tweet: DPR RI undang ichsan YL rumuskan RUU kepalang merahan...
# GT: positive | Pred: negative | Score: -0.629
# --------------------------------------------------------------------------------
# Tweet: assalamualaikum pak fakhri hamzah yang terhormat yang di amanah kan sebagian wakil DPR RI saya nak u...
# GT: negative | Pred: positive | Score: 0.202
# --------------------------------------------------------------------------------
# Tweet: apa yang telah saya kemukakan di atas menjadi suatu pembenaran dan alasan saya untuk mendukung pemba...
# GT: positive | Pred: negative | Score: -0.771
# --------------------------------------------------------------------------------
# Tweet: anggota DPR apresiasi penghentian kebijakan plastik berbayar...
# GT: positive | Pred: negative | Score: -0.527
# --------------------------------------------------------------------------------
# Tweet: komisi II terima DIM RUU pertanahan dari pemerintah...
# GT: neutral | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: menjadi wakil rakyat di DPR RI bukanlah hal yang patut dibanggakan apalagi di agungkan tetapi ada ha...
# GT: positive | Pred: negative | Score: -0.637
# --------------------------------------------------------------------------------
# Tweet: webinar ini dilatarbelakangi lantaran kekhawatiran DPR RI atas perkembangan situasi palestina khusus...
# GT: positive | Pred: negative | Score: -0.958
# --------------------------------------------------------------------------------
# Tweet: selama DPR telah menyelesaikan RUU nasional RUU DPRRI...
# GT: positive | Pred: neutral | Score: 0.000
# --------------------------------------------------------------------------------
# Tweet: sidang paripurna di DPR RI yang membahas RUU pemilu telah selesai dilaksanakan ach elshintanewsandta...
# GT: neutral | Pred: positive | Score: 0.516
# --------------------------------------------------------------------------------
# Tweet: tindakan yang sangat wajar dan janganlah kamu mengkhianati amanat amanat yang dipercayakan kepadamu ...
# GT: negative | Pred: positive | Score: 0.439
# --------------------------------------------------------------------------------
# Tweet: syarifuddin suding RUU pemilu akan digiring ke pemilu sistem proporsional tertutup...
# GT: neutral | Pred: negative | Score: -0.718
# --------------------------------------------------------------------------------
# Tweet: selamat jalan bhayangkaraku...
# GT: neutral | Pred: positive | Score: 0.202
# --------------------------------------------------------------------------------
# Tweet: soal omicron untuk anggota DPR RI...
# GT: neutral | Pred: negative | Score: -0.368
# --------------------------------------------------------------------------------

# %%
# 4.6 Tabel Metrik Utama
acc = accuracy_score(df_eval['gt_class'], df_eval['pred_class'])
prec = precision_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)
rec = recall_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)
f1 = f1_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)

metrics_df = pd.DataFrame([{
    'Konfigurasi': 'RSN + Ignore',
    'Accuracy': f"{acc:.2f}",
    'Precision (M)': f"{prec:.2f}",
    'Recall (M)': f"{rec:.2f}",
    'F1-Score (M)': f"{f1:.2f}"
}])

metrics_df
# Out:
#     Konfigurasi Accuracy Precision (M) Recall (M) F1-Score (M)
# 0  RSN + Ignore     0.60          0.58       0.57         0.55

# %%
# 4.7 Visualisasi: Scatter Plot dan Regression Line
plt.figure(figsize=(8, 6))

# Scatter Plot: X = Model (-1,1), Y = Human (-1,1)
sns.scatterplot(x=y_model_pred, y=y_human_visual, alpha=0.4, color='black', s=20)

# Garis Merah: Garis regresi ideal (y = x * 4)
x_vals = np.linspace(-1, 1, 100)
y_vals = x_vals 
plt.plot(x_vals, y_vals, color='red', linestyle='--', linewidth=2, label='Perfect Correlation Line')

# Konfigurasi Sumbu
plt.xlim(-1.1, 1.1)
plt.ylim(-1.1, 1.1)
plt.xticks(np.arange(-1, 1.1, 0.5))
plt.yticks(np.arange(-1, 1.1, 0.5))

plt.xlabel('Model Compound Score', fontsize=12, fontweight='bold')
plt.ylabel('Mean of 20 Human Judges', fontsize=12, fontweight='bold')
plt.title(f'Sentiment Correlation\nPearson r = {pearson_r:.2f}', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

os.makedirs(OUTPUT_DIR, exist_ok=True)
plt.savefig(f'{OUTPUT_DIR}/scatter_plot_RSN_with_Ignore.png', dpi=300, bbox_inches='tight')
plt.show()

print("[INFO] Scatter plot tersimpan.")
# Out:
# [INFO] Scatter plot tersimpan.

# %%
# 4.8 Visualisasi Confusion Matrix
plt.figure(figsize=(8, 6))

# Hitung Confusion Matrix
cm = confusion_matrix(df_eval['gt_class'], df_eval['pred_class'], labels=labels)

# Heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Neg', 'Neu', 'Pos'], 
            yticklabels=['Neg', 'Neu', 'Pos'],
            annot_kws={"size": 14, "weight": "bold"})

plt.title('Confusion Matrix (Threshold ±0.05)', fontsize=14, fontweight='bold')
plt.ylabel('Ground Truth (Human)', fontsize=12, fontweight='bold')
plt.xlabel('Prediction (Model)', fontsize=12, fontweight='bold')

plt.savefig(f'{OUTPUT_DIR}/confusion_matrix_RSN_with_Ignore.png', dpi=300, bbox_inches='tight')
plt.show()

print("[INFO] Confusion matrix tersimpan.")
print("[INFO] Proses evaluasi selesai!")
# Out:
# [INFO] Confusion matrix tersimpan.
# [INFO] Proses evaluasi selesai!

# %%
# 4.9 Menyimpan Hasil
prec = precision_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)
rec = recall_score(df_eval['gt_class'], df_eval['pred_class'], average='macro', zero_division=0)

metrics_df = pd.DataFrame([{
    'Konfigurasi': 'RSN+IGNORE',
    'Accuracy': f"{acc:.2f}",
    'Precision (M)': f"{prec:.2f}",
    'Recall (M)': f"{rec:.2f}",
    'F1-Score (M)': f"{f1_macro:.2f}",
    'Pearson-r': f"{pearson_r:.2f}"
}])

# Simpan ke CSV
metrics_df.to_csv(os.path.join(OUTPUT_DIR, 'evaluation_metrics_RSN_with_Ignore.csv'), index=False)

# Simpan JSON Summary
eval_summary = {
    'konfigurasi': 'RSN+IGNORE',
    'dataset_size': len(df_eval),
    'metrics': metrics_df.iloc[0].to_dict()
}
with open(os.path.join(OUTPUT_DIR, 'evaluation_summary_RSN_with_Ignore.json'), 'w') as f:
    json.dump(eval_summary, f, indent=2)

print("\n[INFO] Evaluasi RSN+IGNORE Selesai. Data metrik telah disimpan.")
metrics_df
# Out:
# [INFO] Evaluasi RSN+IGNORE Selesai. Data metrik telah disimpan.
#   Konfigurasi Accuracy Precision (M) Recall (M) F1-Score (M) Pearson-r
# 0  RSN+IGNORE     0.60          0.58       0.57         0.55      0.55
